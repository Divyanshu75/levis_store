# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.levi.in/stores"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers).text

# %%
soup=BeautifulSoup(response,'lxml')

# %%
response
# Out:
# '\n\n<!doctype html>\n<!--[if lt IE 7]> <html class="ie6 oldie" lang="en"> <![endif]-->\n<!--[if IE 7]> <html class="ie7 oldie" lang="en"> <![endif]-->\n<!--[if IE 8]> <html class="ie8 oldie" lang="en"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en"> <!--<![endif]-->\n<head>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!--[if gte IE 9 | !IE]><!-->\n<script src="/on/demandware.static/Sites-LeviIN-Site/-/en_IN/v1680848274927/lib/jquery/jquery-2.1.1.min.js" type="text/javascript"></script>\n<!--<![endif]-->\n<!-- Adding Custom JS in BM -->\n<script src="/on/demandware.static/-/Sites-LeviIN-Library/en_IN/v1680848274927/custom-js/local-sitewide-js.js" type="text/javascript"></script>\n<script>window.dataLayer = window.dataLayer || [];</script>\n\n\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.sta
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="ie6 oldie" lang="en"> <![endif]-->
# <!--[if IE 7]> <html class="ie7 oldie" lang="en"> <![endif]-->
# <!--[if IE 8]> <html class="ie8 oldie" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <head>
#   <!--[if gte IE 9 | !IE]><!-->
#   <script src="/on/demandware.static/Sites-LeviIN-Site/-/en_IN/v1680848274927/lib/jquery/jquery-2.1.1.min.js" type="text/javascript">
#   </script>
#   <!--<![endif]-->
#   <!-- Adding Custom JS in BM -->
#   <script src="/on/demandware.static/-/Sites-LeviIN-Library/en_IN/v1680848274927/custom-js/local-sitewide-js.js" type="text/javascript">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# ...

# %%
adress=[]
for i in soup.find_all("table", class_="item-list"):
  adress.append(i.text.strip())

# %% [markdown]
# paragraphs = soup.find_all("p")
# for p in paragraphs:
#     text = p.getText()

# %%
table=soup.find_all("table",class_="item-list")
name=soup.find_all("div",class_="store-name")
name=[]
for i in table:
    text=i.get_text()
    print(text)
    name=i.find_all("div",class_="store-name")
    print(name)
# Out:
# Stores
#
#
#
#
#
# Store Name & Address
# Store Timings
# Telephone Number
#
#
#
#
#
#
#
# Levi's Exclusive Store
#
#
#
# Levi Store Infinity Malad, Upper Ground floor, Next To D-Mart,,
# MH
# ,
#
#
# Malad Link Road, Malad
#
#
#
#
#
#
#
#
#
#
# 022-28441670
#
#
#
# Get Directions
#
#
#
#
#
#
#
#
# Levi's Exclusive Store
#
#
#
# G-1, Om Tower, Shop No 15-16, Scheme No-8, Near Ambedkar Circile,
# RJ
# ,
#
#
#
#
#
#
#
#
#
#
# 0144-2702523
#
#
#
# Get Directions
#
#
#
#
#
#
#
#
# Levi's Exclusive Store
#
#
#
# Levis store, c/o-New Emotions Patna, Savitri Commercial, Complex,,
# BR
# ,
#
#
# Boring Rd
#
#
#
#
#
#
#
#
#
#
# 8873269186
#
#
#
# Get Directions
#
#
#
#
#
#
#
#
# Levi's Exclusive Store
#
#
#
# Mahagun Metro Mall, Shop no 3,Ground floor ,
# UP
# ,
#
#
#
#
#
#
#
#
#
#
# 0120-4242405
#
#
#
# Get Directions
#
#
#
#
#
#
#
#
# Levi's Exclusive Store
#
#
#
# Levi’s Store, Unit No. G-17,18 Ground Floor, Sunshine Building, ,
# GA
# ,
#
#
# ...

# %%
id="store-location-results"

# %%
for i in soup.find_all("div",class_="store-name"):
  print(i.text.strip())
# Out:
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store
# Levi's Exclusive Store

# %%
for i in soup.find_all("div",class_="store-address"):
  print(i.text.strip())
# Out:
# Levi Store Infinity Malad, Upper Ground floor, Next To D-Mart,,
# MH
# ,
#
#
# Malad Link Road, Malad
# G-1, Om Tower, Shop No 15-16, Scheme No-8, Near Ambedkar Circile,
# RJ
# ,
# Levis store, c/o-New Emotions Patna, Savitri Commercial, Complex,,
# BR
# ,
#
#
# Boring Rd
# Mahagun Metro Mall, Shop no 3,Ground floor ,
# UP
# ,
# Levi’s Store, Unit No. G-17,18 Ground Floor, Sunshine Building, ,
# GA
# ,
#
#
# Opp. Hindu Pharmacy, Minguel Loyola Furtado Road, Margao
# Mahagun Metro Mall, Shop no 3,Ground floor ,
# UP
# ,
# Mahagun Metro Mall, Shop no 3,Ground floor ,
# UP
# ,
# 17, GF Pink Square Govind Marg, Janta Colony,
# RJ
# ,
# Mahagun Metro Mall, Shop no 3,Ground floor ,
# UP
# ,
# 11/8 Govind Marg, Rajapark ,
# MH
# ,
# Levis Store, No:29 Thillai Nagar main Road,
# TN
# ,
# B 19, Rahul Raj Mall, Near Goverdan Haweli, Dumas Road,
#
# Surat,
#
#
#
#
# 395007
# Shop No. 3 & 4-C 19/187-A1, Mohalla Gulabh Bagh Sigra,
#
# Varanasi,
#
#
#
#
# 221002
# ...

# %%
table=soup.find_all("td",class_="store-information")

# %%
len(table)
# Out:
# 20

# %%
name=[]
address=[]
number=[]
time=[]

for i in table:
    name.append(i.find("div",class_="store-name").text.strip())
    adress=i.find("div",class_="store-address")
    address.append(adress.text.strip())

# %%
number=[]
for i in soup.find_all("div",class_="call-me"):
  number.append(i.text.strip())

# %%
len(number)
# Out:
# 20

# %%
time=[]
for i in soup.find_all("td",class_="store-timings"):
  time.append(i.text.strip())

# %%
len(time)
# Out:
# 20

# %%
soup.find_all("span",class_="call-me")
# Out:
# []

# %%
address = [address for address in address if address.strip()]
('\n'.join(address))
# Out:
# 'Levi Store Infinity Malad, Upper Ground floor, Next To D-Mart,,\nMH\n,\n\n\nMalad Link Road, Malad\nG-1, Om Tower, Shop No 15-16, Scheme No-8, Near Ambedkar Circile,\nRJ\n,\nLevis store, c/o-New Emotions Patna, Savitri Commercial, Complex,,\nBR\n,\n\n\nBoring Rd\nMahagun Metro Mall, Shop no 3,Ground floor ,\nUP\n,\nLevi’s Store, Unit No. G-17,18 Ground Floor, Sunshine Building, ,\nGA\n,\n\n\nOpp. Hindu Pharmacy, Minguel Loyola Furtado Road, Margao\nMahagun Metro Mall, Shop no 3,Ground floor ,\nUP\n,\nMahagun Metro Mall, Shop no 3,Ground floor ,\nUP\n,\n17, GF Pink Square Govind Marg, Janta Colony,\nRJ\n,\nMahagun Metro Mall, Shop no 3,Ground floor ,\nUP\n,\n11/8 Govind Marg, Rajapark ,\nMH\n,\nLevis Store, No:29 Thillai Nagar main Road,\nTN\n,\nB 19, Rahul Raj Mall, Near Goverdan Haweli, Dumas Road,\n\nSurat,\n\n\n\n\n395007\nShop No. 3 & 4-C 19/187-A1, Mohalla Gulabh Bagh Sigra,\n\nVaranasi,\n\n\n\n\n221002\nGF-16, Sher Singh Palace, GT Road, Gandhi Nagar,\n\nGhaziabad,\n\n\n\n\n20
# ...

# %%
data = {"Store Name": name, "Address": address, "Time": time,"Number":number}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Write the DataFrame to an Excel file
df.to_excel("stores.xlsx", index=False)

# %%
df = pd.read_excel('stores.xlsx')

df.to_csv('stores.csv', index=False)

# %%
df=pd.read_csv("stores.csv")
